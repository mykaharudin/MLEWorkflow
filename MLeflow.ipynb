# %% [markdown]
# #  Data Collection and Data Load

# %%
import pandas as pd 
dataTest = pd.read_csv('data/all_perth_310121.csv')
dataTest.head()
# Out:
#            ADDRESS      SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0    1 Acorn Place  South Lake  565000         4          2     2.0
# 1      1 Addis Way       Wandi  365000         3          2     2.0
# 2  1 Ainsley Court     Camillo  287000         3          1     1.0
# 3  1 Albert Street    Bellevue  255000         2          1     2.0
# 4     1 Aman Place   Lockridge  325000         4          1     2.0
#
#    LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0        600         160      2003.0     18300  Cockburn Central Station
# 1        351         139      2013.0     26900           Kwinana Station
# 2        719          86      1979.0     22600           Challis Station
# 3        651          59      1953.0     17900           Midland Station
# 4        466         131      1998.0     11200        Bassendean Station
#
#    NEAREST_STN_DIST  DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# ...

# %% [markdown]
# # Data Cleaning dan Transformation

# %%
dataTest.info() # Menampilkan ringkasan informasi dari dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33656 entries, 0 to 33655
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ADDRESS           33656 non-null  object
#  1   SUBURB            33656 non-null  object
#  2   PRICE             33656 non-null  int64
#  3   BEDROOMS          33656 non-null  int64
#  4   BATHROOMS         33656 non-null  int64
#  5   GARAGE            31178 non-null  float64
#  6   LAND_AREA         33656 non-null  int64
#  7   FLOOR_AREA        33656 non-null  int64
#  8   BUILD_YEAR        30501 non-null  float64
#  9   CBD_DIST          33656 non-null  int64
#  10  NEAREST_STN       33656 non-null  object
#  11  NEAREST_STN_DIST  33656 non-null  int64
#  12  DATE_SOLD         33656 non-null  object
#  13  POSTCODE          33656 non-null  int64
#  14  LATITUDE          33656 non-null  float64
#  15  LONGITUDE         33656 non-null  float64
# ...

# %%
# Menampilkan statistik deskriptif dari dataset
dataTest.describe(include="all")
# Out:
#             ADDRESS   SUBURB         PRICE      BEDROOMS     BATHROOMS  \
# count         33656    33656  3.365600e+04  33656.000000  33656.000000
# unique        33566      321           NaN           NaN           NaN
# top     123 Fairway  Bertram           NaN           NaN           NaN
# freq              3      231           NaN           NaN           NaN
# mean            NaN      NaN  6.370720e+05      3.659110      1.823063
# std             NaN      NaN  3.558256e+05      0.752038      0.587427
# min             NaN      NaN  5.100000e+04      1.000000      1.000000
# 25%             NaN      NaN  4.100000e+05      3.000000      1.000000
# 50%             NaN      NaN  5.355000e+05      4.000000      2.000000
# 75%             NaN      NaN  7.600000e+05      4.000000      2.000000
# max             NaN      NaN  2.440000e+06     10.000000     16.000000
#
#               GARAGE      LAND_AREA    FLOOR_AREA    BUILD_YEAR      CBD_DIST  \
# ...

# %%
# Memeriksa jumlah nilai yang hilang di setiap kolom
missing_values = dataTest.isnull().sum()
missing_values[missing_values > 0]
# Out:
# GARAGE               2478
# BUILD_YEAR           3155
# NEAREST_SCH_RANK    10952
# dtype: int64

# %% [markdown]
# **Mengatasi Missing Value**

# %%
less = missing_values[missing_values < 1000].index
over = missing_values[missing_values >= 1000].index

# %%
# Contoh mengisi nilai yang hilang dengan median untuk kolom numerik
numeric_features = dataTest[less].select_dtypes(include=['number']).columns
dataTest[numeric_features] = dataTest[numeric_features].fillna(dataTest[numeric_features].median())

# %%
# Contoh mengisi nilai yang hilang dengan median untuk kolom kategori
kategorical_features = dataTest[less].select_dtypes(include=['object']).columns

for column in kategorical_features.index:
    dataTest[column] = dataTest[column].fillna(dataTest[column].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Contoh mengisi nilai yang hilang dengan median untuk kolom kategori
#       2 kategorical_features = dataTest[less].select_dtypes(include=['object']).columns
# ----> 4 for column in kategorical_features.IndexError:
#       5     dataTest[column] = dataTest[column].fillna(dataTest[column].mode()[0])
#
# AttributeError: 'Index' object has no attribute 'IndexError'
